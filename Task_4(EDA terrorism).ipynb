# %% [markdown]
# # Task: EDA terrorism

# %%
# importing all imp libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import warnings

# %%
df = pd.read_csv('Task_4global terrorism.csv',encoding='cp1252')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# check the size of this csv
df.size
# Out:
# 24528285

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
# check the colom namdf.columns
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df = df[['iyear','imonth','iday','extended','country_txt','region_txt','city','success','suicide','attacktype1_txt',
         'targtype1_txt','gname','weaptype1_txt','nkill']]
df.head(8)
# Out:
#    iyear  imonth  iday  extended         country_txt  \
# 0   1970       7     2         0  Dominican Republic
# 1   1970       0     0         0              Mexico
# 2   1970       1     0         0         Philippines
# 3   1970       1     0         0              Greece
# 4   1970       1     0         0               Japan
# 5   1970       1     1         0       United States
# 6   1970       1     2         0             Uruguay
# 7   1970       1     2         0       United States
#
#                     region_txt           city  success  suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
# 5                North America          Cairo        1        0
# 6                South America     Montevideo        0        0
# 7                North America        Oakland        1        0
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
# 5                   Armed Assault                       Police
# 6                   Assassination                       Police
# 7               Bombing/Explosion                    Utilities
#
#                                 gname weaptype1_txt  nkill
# 0                              MANO-D       Unknown    1.0
# 1  23rd of September Communist League       Unknown    0.0
# 2                             Unknown       Unknown    1.0
# 3                             Unknown    Explosives    NaN
# 4                             Unknown    Incendiary    NaN
# 5                  Black Nationalists      Firearms    0.0
# 6                 Tupamaros (Uruguay)      Firearms    0.0
# 7                             Unknown    Explosives    0.0

# %%
# rename the column 
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','extended':'Extended','country_txt':'Country',
                   'region_txt':'Region','city':'City','success':'Success','suicide':'Suicide','attacktype1_txt':'Attack Type',
                   'targtype1_txt':'Target Type','gname':'Attack Group',
                   'weaptype1_txt':'Weapon Type','nkill':'No. of killings'},inplace=True)

# %%
df.head(10)
# Out:
#    Year  Month  Day  Extended             Country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
# 5  1970      1    1         0       United States
# 6  1970      1    2         0             Uruguay
# 7  1970      1    2         0       United States
# 8  1970      1    2         0       United States
# 9  1970      1    3         0       United States
#
#                         Region           City  Success  Suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
# 5                North America          Cairo        1        0
# 6                South America     Montevideo        0        0
# 7                North America        Oakland        1        0
# 8                North America        Madison        1        0
# 9                North America        Madison        1        0
#
#                       Attack Type                  Target Type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
# 5                   Armed Assault                       Police
# 6                   Assassination                       Police
# 7               Bombing/Explosion                    Utilities
# 8  Facility/Infrastructure Attack                     Military
# 9  Facility/Infrastructure Attack         Government (General)
#
#                          Attack Group Weapon Type  No. of killings
# 0                              MANO-D     Unknown              1.0
# 1  23rd of September Communist League     Unknown              0.0
# 2                             Unknown     Unknown              1.0
# 3                             Unknown  Explosives              NaN
# 4                             Unknown  Incendiary              NaN
# 5                  Black Nationalists    Firearms              0.0
# 6                 Tupamaros (Uruguay)    Firearms              0.0
# 7                             Unknown  Explosives              0.0
# 8                     New Year's Gang  Incendiary              0.0
# 9                     New Year's Gang  Incendiary              0.0

# %%
df.dtypes
# Out:
# Year                 int64
# Month                int64
# Day                  int64
# Extended             int64
# Country             object
# Region              object
# City                object
# Success              int64
# Suicide              int64
# Attack Type         object
# Target Type         object
# Attack Group        object
# Weapon Type         object
# No. of killings    float64
# dtype: object

# %%
df.describe() # its used to find statistics
# Out:
#                 Year          Month            Day       Extended  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644       0.045346
# std        13.259430       3.388303       8.814045       0.208063
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#              Success        Suicide  No. of killings
# count  181691.000000  181691.000000    171378.000000
# mean        0.889598       0.036507         2.403272
# std         0.313391       0.187549        11.545741
# min         0.000000       0.000000         0.000000
# 25%         1.000000       0.000000         0.000000
# 50%         1.000000       0.000000         0.000000
# 75%         1.000000       0.000000         2.000000
# max         1.000000       1.000000      1570.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             181691 non-null  int64
#  1   Month            181691 non-null  int64
#  2   Day              181691 non-null  int64
#  3   Extended         181691 non-null  int64
#  4   Country          181691 non-null  object
#  5   Region           181691 non-null  object
#  6   City             181257 non-null  object
#  7   Success          181691 non-null  int64
#  8   Suicide          181691 non-null  int64
#  9   Attack Type      181691 non-null  object
#  10  Target Type      181691 non-null  object
#  11  Attack Group     181691 non-null  object
#  12  Weapon Type      181691 non-null  object
#  13  No. of killings  171378 non-null  float64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 19.4+ MB

# %%
df.describe(include='O')
# Out:
#        Country                      Region     City        Attack Type  \
# count   181691                      181691   181257             181691
# unique     205                          12    36674                  9
# top       Iraq  Middle East & North Africa  Unknown  Bombing/Explosion
# freq     24636                       50474     9775              88255
#
#                         Target Type Attack Group Weapon Type
# count                        181691       181691      181691
# unique                           22         3537          12
# top     Private Citizens & Property      Unknown  Explosives
# freq                          43511        82782       92426

# %%
df['No. of killings'] = df['No. of killings'].fillna(0)

# %%
df['No. of killings']=df['No. of killings'].astype('int')
df.head()
# Out:
#    Year  Month  Day  Extended             Country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
#
#                         Region           City  Success  Suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
#
#                       Attack Type                  Target Type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                          Attack Group Weapon Type  No. of killings
# 0                              MANO-D     Unknown                1
# 1  23rd of September Communist League     Unknown                0
# 2                             Unknown     Unknown                1
# 3                             Unknown  Explosives                0
# 4                             Unknown  Incendiary                0

# %%
#check for duplicates values
df[df.duplicated()].shape
# Out:
# (15707, 14)

# %%
df.shape
# Out:
# (181691, 14)

# %%
df.drop_duplicates(inplace=True)  # drop duplicate values

# %%
df.shape
# Out:
# (165984, 14)

# %%
df.describe()
# Out:
#                 Year          Month            Day       Extended  \
# count  165984.000000  165984.000000  165984.000000  165984.000000
# mean     2003.096461       6.469943      15.523159       0.048161
# std        13.150953       3.390285       8.815357       0.214108
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#              Success        Suicide  No. of killings
# count  165984.000000  165984.000000    165984.000000
# mean        0.887965       0.039022         2.430373
# std         0.315410       0.193648        11.703920
# min         0.000000       0.000000         0.000000
# 25%         1.000000       0.000000         0.000000
# 50%         1.000000       0.000000         0.000000
# 75%         1.000000       0.000000         2.000000
# max         1.000000       1.000000      1570.000000

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x=df['Year'],y=df['No. of killings'])
plt.xticks(rotation=90)
plt.show()

# %%
#Check the missing values
total=(df.isnull().sum()).sort_values(ascending=False)
percent=(df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)

# %%
null_data=pd.concat([total,percent],axis=1,keys=['Total','percentage'])
null_data
# Out:
#                  Total  percentage
# City               411    0.002476
# Year                 0    0.000000
# Month                0    0.000000
# Day                  0    0.000000
# Extended             0    0.000000
# Country              0    0.000000
# Region               0    0.000000
# Success              0    0.000000
# Suicide              0    0.000000
# Attack Type          0    0.000000
# Target Type          0    0.000000
# Attack Group         0    0.000000
# Weapon Type          0    0.000000
# No. of killings      0    0.000000

# %%
# now fill name with Unknown names
df['City']=df['City'].fillna('Unknown')

# %%
null_data
# Out:
#                  Total  percentage
# City               411    0.002476
# Year                 0    0.000000
# Month                0    0.000000
# Day                  0    0.000000
# Extended             0    0.000000
# Country              0    0.000000
# Region               0    0.000000
# Success              0    0.000000
# Suicide              0    0.000000
# Attack Type          0    0.000000
# Target Type          0    0.000000
# Attack Group         0    0.000000
# Weapon Type          0    0.000000
# No. of killings      0    0.000000

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(15,15))
df['Year'].value_counts().plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(15,8))
df['Country'].value_counts().iloc[0:10].plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(15,15))
df['City'].value_counts().iloc[0:10].plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(15,8))
df['Region'].value_counts().iloc[:10].plot(kind='bar')
plt.show()

# %%
values=df['Attack Type'].value_counts()
names=df['Attack Type'].unique().tolist()
plt.pie(values,labels=names,radius=2,autopct='%1.1f%%')
plt.show()
print(values/len(df['Attack Type']))
# Out:
# Bombing/Explosion                      0.468822
# Armed Assault                          0.245241
# Assassination                          0.112131
# Hostage Taking (Kidnapping)            0.065229
# Facility/Infrastructure Attack         0.052921
# Unknown                                0.040793
# Hostage Taking (Barricade Incident)    0.005482
# Unarmed Assault                        0.005476
# Hijacking                              0.003904
# Name: Attack Type, dtype: float64

# %%
most_attacking_groups=df[df['Attack Group'].isin(df['Attack Group'].value_counts()[1:11].index)]
pd.crosstab(most_attacking_groups.Year,most_attacking_groups['Attack Group']).plot(color=sns.color_palette('Paired',15))
fig=plt.gcf()
fig.set_size_inches(15,8)
plt.title("Top 10 attacking groups")
plt.show()

# %%
sns.countplot(x=df['Region'],hue=df['Weapon Type'])
plt.xticks(rotation=180)
plt.show()

# %%
sns.countplot(df['Attack Type'],hue=df['Success'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\vidne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Region'],hue=df['Suicide'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\vidne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
